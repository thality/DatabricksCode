# %%
blob_account_name = "NAME_BLOB"
blob_container_name = "NAME_CONTAINER"
blob_relative_path = "CAMINHO DO ARQUIVO"
blob_sas_token = r"SEU_TOKEN"

# %%
wasbs_path = 'wasbs://%s@%s.blob.core.windows.net/%s' % (blob_container_name, blob_account_name, blob_relative_path)
spark.conf.set('fs.azure.sas.%s.%s.blob.core.windows.net' % (blob_container_name, blob_account_name), blob_sas_token)
print('Remote blob path: ' + wasbs_path)

# %%
try:
  file = spark.read.format('json').load(wasbs_path)
except:
  print('Erro')

# %%
# info para a conexão com o cosmos
URI = "https://cosmos-thalita.documents.azure.com:443/"
PrimaryKey = "J9yJ0aKBOgPmcjMpiXLuraxbzFvfuHe7s4YNhcvkP6BKS7tyK5FssUIOVCpl8XkwbJSEOZcrnpsAN9ialJLgQvp9Dw=="

# %%
#conexão com o cosmos 

CosmosDatabase = "nbateste"
CosmosCollection = "c-test"

config = {
    "spark.cosmos.accountEndpoint": URI,
    "spark.cosmos.accountKey": PrimaryKey,
    "spark.cosmos.database": CosmosDatabase,
    "spark.cosmos.container": CosmosCollection
}

# %%
# Leitura de dados no Cosmos
df = spark.read.format("cosmos.oltp").options(**config).load()

# %%
#Escrever de dados no Cosmos
df.write.format("cosmos.oltp").mode("APPEND").options(**config).save()

# %%
# Instalar essa biblioteca no cluster
com.azure.cosmos.spark:azure-cosmos-spark_3-1_2-12:4.2.0
